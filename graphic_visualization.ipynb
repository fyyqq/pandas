# %%
import pandas
import seaborn

# %%
data = pandas.read_csv('../../data/kapal_titanic.csv')

# %%
data.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %%
data['survived'].hist()
# Out:
# <Axes: >

# %%
# data['age'].hist()
data['age'].head().hist()
# data['age'].head().hist(bins=10)
# Out:
# <Axes: >

# %%
data.age.plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
seaborn.set()
data.age.plot.hist(bins=30, alpha=.5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import numpy

# %%
numpy.random.seed(100)

# %%
numbers = [i for i in range(100)]

# %%
newData = pandas.DataFrame(numpy.random.rand(100, 5), numbers, ['A', 'B', 'C', 'D', 'E'])

# %%
# newData
newData.plot.area()
# Out:
# <Axes: >

# %%
newData.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
newData['B'].plot.bar()
# Out:
# <Axes: >

# %%
newData.plot.scatter(x='A', y='B', c='E', cmap='ocean')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
newData.plot.scatter(x='A', y='B', s=newData.D*100, c='B')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
newData.plot.box()
# Out:
# <Axes: >

# %%
newData.plot.line(y='B', lw=1, figsize=(15, 5))
# Out:
# <Axes: >

# %%
newData.plot.hexbin(x='A', y='B', gridsize=22)
# Out:
# <Axes: xlabel='A', ylabel='B'>
