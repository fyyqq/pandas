# %%
import pandas

myData = pandas.read_csv('kapal_titanic.csv')
myData.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
myData.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %%
myData.to_csv('datacsv.csv', index=False)

# %%
pandas.read_csv('datacsv.csv')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
myData.to_excel('dataexcel.xlsx', index=False, sheet_name='asik')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# c:\Users\User\Desktop\Python\pandas\index.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Python/pandas/index.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> myData.to_excel('dataexcel.xlsx', index=False, sheet_name='asik')
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:2345, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2332 from pandas.io.formats.excel import ExcelFormatter
#    2334 formatter = ExcelFormatter(
#    2335     df,
#    2336     na_rep=na_rep,
#    (...)
#    2343     inf_rep=inf_rep,
#    2344 )
# -> 2345 formatter.write(
#    2346     excel_writer,
# ...

# %%
pandas.read_excel('dataexcel.xlsx', sheet_name='asik')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
datahtml = pandas.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')
print(datahtml)
# Out:
# [                         Bank NameBank       CityCity StateSt  CertCert  \
# 0                        Citizens Bank       Sac City      IA      8758
# 1             Heartland Tri-State Bank        Elkhart      KS     25851
# 2                  First Republic Bank  San Francisco      CA     59017
# 3                       Signature Bank       New York      NY     57053
# 4                  Silicon Valley Bank    Santa Clara      CA     24735
# ..                                 ...            ...     ...       ...
# 563                 Superior Bank, FSB       Hinsdale      IL     32646
# 564                Malta National Bank          Malta      OH      6629
# 565    First Alliance Bank & Trust Co.     Manchester      NH     34264
# 566  National State Bank of Metropolis     Metropolis      IL      3815
# 567                   Bank of Honolulu       Honolulu      HI     21029
#
#                  Acquiring InstitutionAI Closing DateClosing  FundFund
# ...

# %%
from sqlalchemy import create_engine

# %%
machine = create_engine('sqlite:///:memory:')

# %%
myData.to_sql('datasql', con=machine)
pandas.read_sql('datasql', con=machine)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\User\Desktop\Python\pandas\index.ipynb Cell 10 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Python/pandas/index.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> myData = pandas.read_csv('kapal_titanic.csv')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Python/pandas/index.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> myData.to_sql('datasql', con=machine)
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Python/pandas/index.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> pandas.read_sql('datasql', con=machine)
#
# NameError: name 'machine' is not defined
