# %%
import pandas


myData = pandas.read_csv('kapal_titanic.csv')

# %%
data = myData['sex']

# %%
myData[['sex', 'fare']]
# Out:
#         sex     fare
# 0      male   7.2500
# 1    female  71.2833
# 2    female   7.9250
# 3    female  53.1000
# 4      male   8.0500
# ..      ...      ...
# 886    male  13.0000
# 887  female  30.0000
# 888  female  23.4500
# 889    male  30.0000
# 890    male   7.7500
#
# [891 rows x 2 columns]

# %%
myData[['age']]
# Out:
#       age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
myData.sex
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: sex, Length: 891, dtype: object

# %%
myData['sex'].equals(myData.sex)
# Out:
# True

# %%
myData.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked deck
# 0         0       3  male  22.0      1      0  7.25        S  NaN

# %%
myData.iloc[888:]
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %%
myData.iloc[1:4, 2:4]
# Out:
#       sex   age
# 1  female  38.0
# 2  female  26.0
# 3  female  35.0

# %%
myData.iloc[[1, 2, 3], [1, 2, 3]]
# Out:
#    pclass     sex   age
# 1       1  female  38.0
# 2       3  female  26.0
# 3       1  female  35.0

# %%
newData = pandas.read_csv('kapal_titanic.csv', index_col='embarked')

# %%
newData
# Out:
#           survived  pclass     sex   age  sibsp  parch     fare deck
# embarked
# S                0       3    male  22.0      1      0   7.2500  NaN
# C                1       1  female  38.0      1      0  71.2833    C
# S                1       3  female  26.0      0      0   7.9250  NaN
# S                1       1  female  35.0      1      0  53.1000    C
# S                0       3    male  35.0      0      0   8.0500  NaN
# ...            ...     ...     ...   ...    ...    ...      ...  ...
# S                0       2    male  27.0      0      0  13.0000  NaN
# S                1       1  female  19.0      0      0  30.0000    B
# S                0       3  female   NaN      1      2  23.4500  NaN
# C                1       1    male  26.0      0      0  30.0000    C
# Q                0       3    male  32.0      0      0   7.7500  NaN
#
# [891 rows x 8 columns]

# %%
newData.loc['S', ['age', 'fare']]
# Out:
#            age     fare
# embarked
# S         22.0   7.2500
# S         26.0   7.9250
# S         35.0  53.1000
# S         35.0   8.0500
# S         54.0  51.8625
# ...        ...      ...
# S         28.0  10.5000
# S         25.0   7.0500
# S         27.0  13.0000
# S         19.0  30.0000
# S          NaN  23.4500
#
# [644 rows x 2 columns]

# %%
newData.loc[['S', 'Q'], ['age', 'fare']]
# Out:
#            age     fare
# embarked
# S         22.0   7.2500
# S         26.0   7.9250
# S         35.0  53.1000
# S         35.0   8.0500
# S         54.0  51.8625
# ...        ...      ...
# Q          NaN   7.7500
# Q          NaN   6.9500
# Q          NaN   7.7500
# Q         39.0  29.1250
# Q         32.0   7.7500
#
# [721 rows x 2 columns]
