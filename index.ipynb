# %%
import pandas as pd
import matplotlib.pyplot as plt

# Membuat DataFrame contoh
data = {'Category': ['A', 'B', 'C', 'D'],
        'Values': [10, 30, 20, 25]}

df = pd.DataFrame(data)

# Menghasilkan bar chart
df.plot(kind='bar', x='Category', y='Values', legend=False)
plt.title('Bar Chart')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Membuat DataFrame contoh
data = {'X': [1, 2, 3, 4],
        'Y': [10, 20, 25, 30]}

df = pd.DataFrame(data)

# Menghasilkan line chart
df.plot(kind='line', x='X', y='Y', marker='o')
plt.title('Line Chart')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Membuat DataFrame contoh
data = {'X': [1, 2, 3, 4],
        'Y': [10, 20, 25, 30]}

df = pd.DataFrame(data)

# Menghasilkan scatter plot
df.plot(kind='scatter', x='X', y='Y', color='red')
plt.title('Scatter Plot')
plt.show()

# %%
data = {
    'Category': ['A', 'B', 'C', 'D'],
    'Values': [10, 30, 20, 25]
}

# %%
import pandas

pandas.DataFrame(data)
# Out:
#   Category  Values
# 0        A      10
# 1        B      30
# 2        C      20
# 3        D      25

# %%
pandas.Series(data)
# Out:
# Category        [A, B, C, D]
# Values      [10, 30, 20, 25]
# dtype: object

# %%
import pandas
import numpy

# %%
rand = numpy.random.rand(2, 5)
index = [i for i in range(len(rand))]

# %%
data1 = pandas.DataFrame(list(rand), index, ['A', 'B', 'C', 'D', 'E'])

# %%
data2 = pandas.DataFrame(list(rand), index, ['A', 'B', 'C', 'D', 'E'])

# %%
pandas.concat([data1, data2])
# Out:
#           A         B         C         D         E
# 0  0.982991  0.719012  0.682407  0.366016  0.766939
# 1  0.205996  0.901629  0.169369  0.197212  0.915751
# 0  0.982991  0.719012  0.682407  0.366016  0.766939
# 1  0.205996  0.901629  0.169369  0.197212  0.915751

# %%
x_data = pandas.DataFrame({ 'key1': ['A', 'B', 'C'], 'key2': [1, 2, 3], 'value_x': [10, 20, 30] })
y_data = pandas.DataFrame({ 'key1': ['A', 'B', 'D'], 'key2': [1, 2, 4], 'value_y': [40, 50, 60] })

# %%
x_data
# Out:
#   key1  key2  value_x
# 0    A     1       10
# 1    B     2       20
# 2    C     3       30

# %%
y_data
# Out:
#   key1  key2  value_y
# 0    A     1       40
# 1    B     2       50
# 2    D     4       60

# %%
# normal merge
pandas.merge(x_data, y_data)
# Out:
#   key1  key2  value_x  value_y
# 0    A     1       10       40
# 1    B     2       20       50

# %%
# left merge
pandas.merge(x_data, y_data, how='left', on=['key1', 'key2'])
# Out:
#   key1  key2  value_x  value_y
# 0    A     1       10     40.0
# 1    B     2       20     50.0
# 2    C     3       30      NaN

# %%
# right merge
pandas.merge(x_data, y_data, how='right', on=['key1', 'key2'])
# Out:
#   key1  key2  value_x  value_y
# 0    A     1     10.0       40
# 1    B     2     20.0       50
# 2    D     4      NaN       60

# %%
# outer merge
pandas.merge(x_data, y_data, how='outer', on=['key1', 'key2'])
# Out:
#   key1  key2  value_x  value_y
# 0    A     1     10.0     40.0
# 1    B     2     20.0     50.0
# 2    C     3     30.0      NaN
# 3    D     4      NaN     60.0

# %%
# inner merge
pandas.merge(x_data, y_data, how='inner', on=['key1', 'key2'])
# Out:
#   key1  key2  value_x  value_y
# 0    A     1       10       40
# 1    B     2       20       50

# %%
titanic = pandas.read_csv('../data/kapal_titanic.csv')

# %%
pandas.DataFrame(titanic)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 0           0       3    male  22.0      1      0    7.2500        S  NaN
# 1           1       1  female  38.0      1      0   71.2833        C    C
# 2           1       3  female  26.0      0      0    7.9250        S  NaN
# 3           1       1  female  35.0      1      0   53.1000        S    C
# 4           0       3    male  35.0      0      0    8.0500        S  NaN
# 5           0       3    male   NaN      0      0    8.4583        Q  NaN
# 6           0       1    male  54.0      0      0   51.8625        S    E
# 7           0       3    male   2.0      3      1   21.0750        S  NaN
# 8           1       3  female  27.0      0      2   11.1333        S  NaN
# 9           1       2  female  14.0      1      0   30.0708        C  NaN
# 10          1       3  female   4.0      1      1   16.7000        S    G
# 11          1       1  female  58.0      0      0   26.5500        S    C
# ...

# %%
import pandas
import numpy

# %%
data = numpy.array(['a', 'b', 'c', 'd', 'e'])

# %%
pandas.Series(data, index=[1, 2, 3, 4, 5])
# Out:
# 1    a
# 2    b
# 3    c
# 4    d
# 5    e
# dtype: object

# %%
pandas.DataFrame(data, index=[1, 2, 3, 4, 5], columns=['letters'])
# Out:
#   letters
# 1       a
# 2       b
# 3       c
# 4       d
# 5       e

# %%
data = {'name': ['Afiq', 'Alisha', 'Dasha', 'Zaid'], 'age': [21, 45, 33, 15]}
pandas.DataFrame(data)
# Out:
#      name  age
# 0    Afiq   21
# 1  Alisha   45
# 2   Dasha   33
# 3    Zaid   15

# %%
data = pandas.read_csv('../data/kapal_titanic.csv')

# %%
pandas.Series(data['age'])
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
# 10      4.0
# 11     58.0
# 12     20.0
# 13     39.0
# 14     14.0
# 15     55.0
# 16      2.0
# 17      NaN
# 18     31.0
# 19      NaN
# 20     35.0
# 21     34.0
# 22     15.0
# 23     28.0
# 24      8.0
# 25     38.0
# 26      NaN
# 27     19.0
# 28      NaN
# 29      NaN
#        ...
# 861    21.0
# 862    48.0
# 863     NaN
# 864    24.0
# 865    42.0
# 866    27.0
# 867    31.0
# 868     NaN
# 869     4.0
# 870    26.0
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 875    15.0
# 876    20.0
# 877    19.0
# 878     NaN
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
pandas.DataFrame(data['sex'])
# Out:
#         sex
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# 5      male
# 6      male
# 7      male
# 8    female
# 9    female
# 10   female
# 11   female
# 12     male
# 13     male
# 14   female
# 15   female
# 16     male
# 17     male
# 18   female
# 19   female
# 20     male
# 21     male
# 22   female
# 23     male
# 24   female
# 25   female
# 26     male
# 27     male
# 28   female
# 29     male
# ..      ...
# 861    male
# 862  female
# 863  female
# 864    male
# 865  female
# 866  female
# 867    male
# 868    male
# 869    male
# 870    male
# 871  female
# 872    male
# 873    male
# 874  female
# 875  female
# 876    male
# 877    male
# 878    male
# 879  female
# 880  female
# 881    male
# 882  female
# 883    male
# 884    male
# 885  female
# 886    male
# 887  female
# 888  female
# 889    male
# 890    male
#
# [891 rows x 1 columns]

# %%
pandas.DataFrame(data["sex"]).iloc[2:5]
# Out:
#       sex
# 2  female
# 3  female
# 4    male

# %%
data = pandas.read_csv('./data/nba.csv')

# %%
data
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
data.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
pandas.DataFrame(data["College"]).tail().fillna("None")
# Out:
#     College
# 453  Butler
# 454    None
# 455    None
# 456  Kansas
# 457    None

# %%
# data.drop('Salary', axis=1, inplace=True)

# %%
data.count()
# Out:
# Name        457
# Team        457
# Number      457
# Position    457
# Age         457
# Height      457
# Weight      457
# College     373
# Salary      446
# dtype: int64

# %%
data.shape
# Out:
# (458, 9)

# %%
data.groupby("College").count().head()
# Out:
#                Name  Team  Number  Position  Age  Height  Weight  Salary
# College
# Alabama           3     3       3         3    3       3       3       3
# Arizona          13    13      13        13   13      13      13      13
# Arizona State     2     2       2         2    2       2       2       2
# Arkansas          3     3       3         3    3       3       3       3
# Baylor            1     1       1         1    1       1       1       1

# %%
# sum(data.Age.head())

# %%
pandas.DataFrame(pandas.concat([data.Name.head(), data.Age.head()]))
# Out:
#                0
# 0  Avery Bradley
# 1    Jae Crowder
# 2   John Holland
# 3    R.J. Hunter
# 4  Jonas Jerebko
# 0           25.0
# 1           25.0
# 2           27.0
# 3           22.0
# 4           29.0

# %%
data[["Number", "Age"]]
# Out:
#      Number   Age
# 0       0.0  25.0
# 1      99.0  25.0
# 2      30.0  27.0
# 3      28.0  22.0
# 4       8.0  29.0
# 5      90.0  29.0
# 6      55.0  21.0
# 7      41.0  25.0
# 8      12.0  22.0
# 9      36.0  22.0
# 10      7.0  24.0
# 11      4.0  27.0
# 12     11.0  27.0
# 13     13.0  20.0
# 14     44.0  26.0
# 15     44.0  27.0
# 16     22.0  24.0
# 17     21.0  28.0
# 18     24.0  21.0
# 19      2.0  32.0
# 20     10.0  22.0
# 21      6.0  26.0
# 22      0.0  23.0
# 23     11.0  28.0
# 24      1.0  21.0
# 25     33.0  26.0
# 26     41.0  25.0
# 27     14.0  26.0
# 28     15.0  28.0
# 29     30.0  27.0
# ..      ...   ...
# 428     8.0  25.0
# 429     5.0  23.0
# 430    23.0  24.0
# 431    17.0  27.0
# 432     4.0  23.0
# 433     9.0  28.0
# 434    35.0  34.0
# 435    11.0  24.0
# 436     0.0  25.0
# 437     3.0  24.0
# 438    44.0  23.0
# 439    24.0  26.0
# 440     2.0  30.0
# 441    21.0  20.0
# 442    33.0  28.0
# 443     3.0  23.0
# 444    10.0  24.0
# 445    11.0  20.0
# ...

# %%
pandas.DataFrame(data.loc[2:5])
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
#
#              College      Salary
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# 4                NaN   5000000.0
# 5                NaN  12000000.0

# %%
pandas.DataFrame(data.loc[[3, 4]])
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#          College     Salary
# 3  Georgia State  1148640.0
# 4            NaN  5000000.0

# %%
data.loc[2, 'College']
# Out:
# 'Boston University'

# %%
titanic = pandas.read_csv('../data/kapal_titanic.csv').head(15)

# %%
titanic
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0          0       3    male  22.0      1      0   7.2500        S  NaN
# 1          1       1  female  38.0      1      0  71.2833        C    C
# 2          1       3  female  26.0      0      0   7.9250        S  NaN
# 3          1       1  female  35.0      1      0  53.1000        S    C
# 4          0       3    male  35.0      0      0   8.0500        S  NaN
# 5          0       3    male   NaN      0      0   8.4583        Q  NaN
# 6          0       1    male  54.0      0      0  51.8625        S    E
# 7          0       3    male   2.0      3      1  21.0750        S  NaN
# 8          1       3  female  27.0      0      2  11.1333        S  NaN
# 9          1       2  female  14.0      1      0  30.0708        C  NaN
# 10         1       3  female   4.0      1      1  16.7000        S    G
# 11         1       1  female  58.0      0      0  26.5500        S    C
# ...

# %%
pandas.DataFrame(titanic.loc[9], ["age", "fare"])
# Out:
#             9
# age      14.0
# fare  30.0708

# %%
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
pandas.DataFrame(data.iloc[[1, 3]])
# Out:
#           Name            Team  Number Position   Age Height  Weight  \
# 1  Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3  R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#          College     Salary
# 1      Marquette  6796117.0
# 3  Georgia State  1148640.0

# %%
pandas.DataFrame(data.iloc[3:5])
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#          College     Salary
# 3  Georgia State  1148640.0
# 4            NaN  5000000.0

# %%
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
pandas.DataFrame(data["College"].head().str.slice(0, 3))
# Out:
#   College
# 0     Tex
# 1     Mar
# 2     Bos
# 3     Geo
# 4     NaN

# %%
dataJson = pandas.read_json('./data/sample4.json')

# %%
dataJson.to_string()
# Out:
# "                                                                                              people\n0   {'firstName': 'Joe', 'lastName': 'Jackson', 'gender': 'male', 'age': 28, 'number': '7349282382'}\n1   {'firstName': 'James', 'lastName': 'Smith', 'gender': 'male', 'age': 32, 'number': '5678568567'}\n2  {'firstName': 'Emily', 'lastName': 'Jones', 'gender': 'female', 'age': 24, 'number': '456754675'}"

# %%
pandas.DataFrame(data.tail().College.dropna())
# Out:
#     College
# 453  Butler
# 456  Kansas

# %%
data1 = pandas.DataFrame(titanic[["sex", "age"]].head())

# %%
data2 = pandas.DataFrame(data[["Name", "Team"]].head())

# %%
data1
# Out:
#       sex   age
# 0    male  22.0
# 1  female  38.0
# 2  female  26.0
# 3  female  35.0
# 4    male  35.0

# %%
data2
# Out:
#             Name            Team
# 0  Avery Bradley  Boston Celtics
# 1    Jae Crowder  Boston Celtics
# 2   John Holland  Boston Celtics
# 3    R.J. Hunter  Boston Celtics
# 4  Jonas Jerebko  Boston Celtics

# %%
data = ["A", "B", "C", "D", "E"]
column = { "Letters": data }
index = numpy.arange(len(data))
pandas.DataFrame(column, index)
# Out:
#   Letters
# 0       A
# 1       B
# 2       C
# 3       D
# 4       E

# %%
data1[data1["sex"] == "male"]
# Out:
#     sex   age
# 0  male  22.0
# 4  male  35.0

# %%
pandas.DataFrame(data1["sex"])
# Out:
#       sex
# 0    male
# 1  female
# 2  female
# 3  female
# 4    male

# %%
pandas.DataFrame(data1.iloc[0])
pandas.DataFrame(data1.loc[0])
# Out:
#         0
# sex  male
# age  22.0

# %%
pandas.DataFrame(data1.loc[0:2])
# Out:
#       sex   age
# 0    male  22.0
# 1  female  38.0
# 2  female  26.0

# %%
pandas.DataFrame(data1.iloc[0:2])
# Out:
#       sex   age
# 0    male  22.0
# 1  female  38.0

# %%
data1.at[2, "sex"] = "male"

# %%
data1["name"].replace("nan", "unknown", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[188], line 1
# ...

# %%
data1[data1["age"] > 30]
# Out:
#       sex   age     name
# 1  female  38.0  unknown
# 3  female  35.0  unknown
# 4    male  35.0  unknown

# %%
delRow = data1[data1["name"] == "unknown"].index
data1.drop(delRow)
# Out:
#     sex   age  name
# 2  male  26.0  male

# %%
data1.rename(columns={"sex": "gender", "name": "names"})
# Out:
#    gender   age    names
# 0    male  22.0  unknown
# 1  female  38.0  unknown
# 2    male  26.0     male
# 3  female  35.0  unknown
# 4    male  35.0  unknown

# %%
pandas.DataFrame(data1[data1["age"] > 30])
# Out:
#       sex   age     name
# 1  female  38.0  unknown
# 3  female  35.0  unknown
# 4    male  35.0  unknown

# %%
pandas.DataFrame(data1.loc[1:3])
# Out:
#       sex   age     name
# 1  female  38.0  unknown
# 2    male  26.0     male
# 3  female  35.0  unknown

# %%
data1.sort_values("age", ascending=True)
# Out:
#       sex   age     name
# 0    male  22.0  unknown
# 2    male  26.0     male
# 3  female  35.0  unknown
# 4    male  35.0  unknown
# 1  female  38.0  unknown

# %%
data1.iloc[::-1]
# Out:
#       sex   age     name
# 4    male  35.0  unknown
# 3  female  35.0  unknown
# 2    male  26.0     male
# 1  female  38.0  unknown
# 0    male  22.0  unknown

# %%
gp = data1.groupby("name")

# %%
for x, y in gp:
    print(y)
# Out:
#     sex   age  name
# 2  male  26.0  male
#       sex   age     name
# 0    male  22.0  unknown
# 1  female  38.0  unknown
# 3  female  35.0  unknown
# 4    male  35.0  unknown

# %%
data1
# Out:
#       sex   age     name
# 0    male  22.0  unknown
# 1  female  38.0  unknown
# 2    male  26.0     male
# 3  female  35.0  unknown
# 4    male  35.0  unknown

# %%
data2
# Out:
#             Name            Team
# 0  Avery Bradley  Boston Celtics
# 1    Jae Crowder  Boston Celtics
# 2   John Holland  Boston Celtics
# 3    R.J. Hunter  Boston Celtics
# 4  Jonas Jerebko  Boston Celtics

# %%
dataframe1 = pandas.DataFrame({
    "key1" : ["A", "B", "C", "D", "E"],
    "data": [1, 2, 3, 4, 5]
})
dataframe2 = pandas.DataFrame({
    "key1" : ["A", "X", "C", "D", "E"],
    "data": [1, 2, 3, 4, 5]
})

# %%
pandas.merge(dataframe1, dataframe2, how="right", on=["key1"])
# Out:
#   key1  data_x  data_y
# 0    A     1.0       1
# 1    X     NaN       2
# 2    C     3.0       3
# 3    D     4.0       4
# 4    E     5.0       5

# %%
pandas.merge(dataframe1, dataframe2, how="left", on="key1")
# Out:
#   key1  data_x  data_y
# 0    A       1     1.0
# 1    B       2     NaN
# 2    C       3     3.0
# 3    D       4     4.0
# 4    E       5     5.0

# %%
pandas.merge(dataframe1, dataframe2, how="outer", on="key1")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\User\Desktop\Python\pandas\index.ipynb Cell 82 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Python/pandas/index.ipynb#Y144sZmlsZQ%3D%3D?line=0'>1</a> pandas.merge(dataframe1, dataframe2, how="outer", on="key1")
#
# NameError: name 'dataframe1' is not defined

# %%
data1["name"] = 'unknown'
data1
# Out:
#       sex   age     name
# 0    male  22.0  unknown
# 1  female  38.0  unknown
# 2    male  26.0  unknown
# 3  female  35.0  unknown
# 4    male  35.0  unknown

# %%
lego = pandas.DataFrame(pandas.read_csv('./data/lego_sets.csv')).tail(50)

# %%
# lego.dropna(subset=["num_parts"])["num_parts"].count()
# lego.dropna(subset=["num_parts"])
# lego["num_parts"].count()
# pandas.DataFrame(lego["num_parts"].dropna())

# %%
# lego.set_index("set_num", inplace=True)
lego.head()
# Out:
#          level_0  index name  year  num_parts theme_name     parent_theme
# set_num
# NaN            0      0  NaN  2015       95.0        NaN  Disney Princess
# NaN            1      1  NaN  2004        NaN        NaN     Harry Potter
# NaN            2      2  NaN  2004        NaN        NaN     Harry Potter
# NaN            3      3  NaN  2013      417.0        NaN     Super Heroes
# NaN            4      4  NaN  2014        NaN        NaN     Super Heroes

# %%
# lego.reset_index(inplace=True)
lego.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\User\Desktop\Python\pandas\index.ipynb Cell 87 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Python/pandas/index.ipynb#Y152sZmlsZQ%3D%3D?line=0'>1</a> # lego.reset_index(inplace=True)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Python/pandas/index.ipynb#Y152sZmlsZQ%3D%3D?line=1'>2</a> lego.head()
#
# NameError: name 'lego' is not defined

# %%
df1 = pandas.DataFrame({'name': ['A', 'B', 'C', 'D'], 'age': [21, 45, 33, 15]})
df2 = pandas.DataFrame({'letter': ['E', 'F', 'G', 'H'], 'age': [34, 25, 53, 12]})
pandas.concat([df1, df2], axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\User\Desktop\Python\pandas\index.ipynb Cell 88 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Python/pandas/index.ipynb#Y153sZmlsZQ%3D%3D?line=0'>1</a> df1 = pandas.DataFrame({'name': ['A', 'B', 'C', 'D'], 'age': [21, 45, 33, 15]})
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Python/pandas/index.ipynb#Y153sZmlsZQ%3D%3D?line=1'>2</a> df2 = pandas.DataFrame({'letter': ['E', 'F', 'G', 'H'], 'age': [34, 25, 53, 12]})
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Python/pandas/index.ipynb#Y153sZmlsZQ%3D%3D?line=2'>3</a> pandas.concat([df1, df2], axis=0)
#
# NameError: name 'pandas' is not defined

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})

result = df.loc[1].apply(lambda x: x * 2)
# result = df.loc[1].transform(lambda x: x * 2)
pd.DataFrame(result)
# Out:
#     1
# A   4
# B  10

# %%
import pandas

gala = pandas.read_csv('./data/HISTORY_6559e40f71d3410001d8c5a6.csv')
gala["Price Buying ($)"] = gala["price"] * gala["size"]
gala["Price Buying ($)"].sum()
gala
# Out:
#         orderCreatedAt                        id  clientOid     symbol side  \
# 0  2023-11-19 17:59:51  6559dc97f8db890007dcc836        NaN  GALA-USDT  buy
# 1  2023-11-13 14:23:39  6551c0eb34d11100077ac0fd        NaN  GALA-USDT  buy
# 2  2023-11-10 22:39:29  654e40a1d9689c00072baad0        NaN  GALA-USDT  buy
# 3  2023-11-04 15:13:01  6545eefd0213850007e9747c        NaN  GALA-USDT  buy
# 4  2023-10-26 11:20:28  6539dafc0e59320007b6b670        NaN  GALA-USDT  buy
# 5  2023-10-11 20:55:21  65269b398619fe0007e63da8        NaN  GALA-USDT  buy
# 6  2023-10-10 20:04:11  65253dbbb1244100074406ff        NaN  GALA-USDT  buy
# 7  2023-09-04 00:24:25  64f4b339b501150007873ea6        NaN  GALA-USDT  buy
#
#     type  stopPrice    price      size  dealSize  dealFunds  averagePrice  \
# 0  limit          0  0.02362  211.0369  211.0369   4.984692       0.02362
# 1  limit          0  0.02350  127.6595  127.6595   2.999998       0.02350
# ...

# %%
vehicle_data = pandas.read_csv('./data/Electric_Vehicle_Population_Data.csv')
vehicle_data[vehicle_data.isna()]
# Out:
#        VIN (1-10) County City State  Postal Code  Model Year Make Model  \
# 0             NaN    NaN  NaN   NaN          NaN         NaN  NaN   NaN
# 1             NaN    NaN  NaN   NaN          NaN         NaN  NaN   NaN
# 2             NaN    NaN  NaN   NaN          NaN         NaN  NaN   NaN
# 3             NaN    NaN  NaN   NaN          NaN         NaN  NaN   NaN
# 4             NaN    NaN  NaN   NaN          NaN         NaN  NaN   NaN
# ...           ...    ...  ...   ...          ...         ...  ...   ...
# 159462        NaN    NaN  NaN   NaN          NaN         NaN  NaN   NaN
# 159463        NaN    NaN  NaN   NaN          NaN         NaN  NaN   NaN
# 159464        NaN    NaN  NaN   NaN          NaN         NaN  NaN   NaN
# 159465        NaN    NaN  NaN   NaN          NaN         NaN  NaN   NaN
# 159466        NaN    NaN  NaN   NaN          NaN         NaN  NaN   NaN
#
#        Electric Vehicle Type  \
# 0                        NaN
# 1                        NaN
# ...

# %% [markdown]
# ### Training Started

# %%
import pandas
import numpy
import matplotlib.pyplot as pylot

# %% [markdown]
# dataframe

# %%
data = {
        'A': [1, 2, 3],
        'B': [4, 5, 6]
    }

pandas.DataFrame(data, index=['a', 'b', 'c'])
# Out:
#    A  B
# a  1  4
# b  2  5
# c  3  6

# %% [markdown]
# series

# %%
data = ['A', 'B', 'C', 'D', 'E']
pandas.Series(data, name="Letters", index=[[letter.lower() for letter in data]])
# Out:
# a    A
# b    B
# c    C
# d    D
# e    E
# Name: Letters, dtype: object

# %%
titanic = pandas.read_csv('./data/Titanic-Dataset.csv')

# %% [markdown]
# loc[ ]

# %%
titanic.loc[2:5, ["Name", "Age", "Sex"]]
titanic.loc[2]["Name"]
titanic.loc[titanic["Age"] < 30]
titanic.loc[(titanic["Age"] > 20) & (titanic["SibSp"] > 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 69            70         0       3
# 85            86         1       3
# 88            89         1       1
# 104          105         0       3
# 120          121         0       2
# 245          246         0       1
# 341          342         1       1
# 392          393         0       3
# 436          437         0       3
# 437          438         1       2
# 529          530         0       2
# 565          566         0       3
# 571          572         1       1
# 600          601         1       2
# 655          656         0       2
# 660          661         1       1
# 665          666         0       2
# 726          727         1       2
# 742          743         1       1
# 860          861         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 69                                   Kink, Mr. Vincenz    male  26.0      2
# ...

# %% [markdown]
# iloc[ ]

# %%
pandas.DataFrame(titanic.iloc[2:5])
titanic.iloc[2]["Name"].split(' ')[2]
# Out:
# 'Laina'

# %% [markdown]
# set_index()

# %%
titanic.set_index('Name')
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# Moran, Mr. James                                              6         0
# McCarthy, Mr. Timothy J                                       7         0
# Palsson, Master. Gosta Leonard                                8         0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)             9         1
# Nasser, Mrs. Nicholas (Adele Achem)                          10         1
# Sandstrom, Miss. Marguerite Rut                              11         1
# Bonnell, Miss. Elizabeth                                     12         1
# ...

# %% [markdown]
# Drop Row with Age is NaN

# %%
# titanic.drop(columns=[titanic.loc[titanic["Age"].isna()]], axis=1)
titanic.dropna(subset=["Age"], axis=0, inplace=True)

# %% [markdown]
# change "Age" float to int

# %%
titanic["Age"] = titanic["Age"].astype(int)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 18            19         0       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 27            28         0       1
# 30            31         0       1
# ...

# %% [markdown]
# isin()

# %%
titanic[(titanic["Age"].isin([20])) & (titanic["Embarked"].isin(["C"]))]
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex  Age  SibSp  \
# 378          379         0       3    Betros, Mr. Tannous  male   20      0
# 622          623         1       3       Nakid, Mr. Sahid  male   20      1
# 762          763         1       3  Barah, Mr. Hanna Assi  male   20      0
#
#      Parch Ticket     Fare Cabin Embarked
# 378      0   2648   4.0125   NaN        C
# 622      1   2653  15.7417   NaN        C
# 762      0   2663   7.2292   NaN        C

# %% [markdown]
# notnull()

# %%
# titanic[titanic["Cabin"].notnull()]

# %% [markdown]
# Create Column & Set The Value

# %%
titanic['Role'] = 'Passenger'
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked       Role
# 0      0         A/5 21171   7.2500   NaN        S  Passenger
# 1      0          PC 17599  71.2833   C85        C  Passenger
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Passenger
# 3      0            113803  53.1000  C123        S  Passenger
# ...

# %% [markdown]
# rename()

# %%
titanic.rename(columns={ 'Embarked' : 'Class' }, inplace=True)

# %%
titanic.rename(index={0 : 'first', 1 : 'second'}).head()
# Out:
#         PassengerId  Survived  Pclass  \
# first             1         0       3
# second            2         1       1
# 2                 3         1       3
# 3                 4         1       1
# 4                 5         0       3
#
#                                                      Name     Sex  Age  SibSp  \
# first                             Braund, Mr. Owen Harris    male   22      1
# second  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                                  Heikkinen, Miss. Laina  female   26      0
# 3            Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                                Allen, Mr. William Henry    male   35      0
#
#         Parch            Ticket     Fare Cabin Class       Role
# first       0         A/5 21171   7.2500   NaN     S  Passenger
# second      0          PC 17599  71.2833   C85     C  Passenger
# 2           0  STON/O2. 3101282   7.9250   NaN     S  Passenger
# ...

# %% [markdown]
# concat()

# %%
# titanic_columns = 'PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Class', 'Role
# titanic2_columns = 'survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'deck'

# titanic2 = pandas.read_csv('./data/kapal_titanic.csv')
# titanics = pandas.concat([titanic, titanic2], axis=1, join='outer')
# titanic.shape # (714, 13)
# titanic2.shape # (891, 9)
pandas.set_option('display.min_rows', None)
# titanics.head()

# df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2'], 'B': ['B0', 'B1', 'B2']})
# df2 = pd.DataFrame({'A': ['A3', 'A4', 'A5'], 'D': ['B3', 'B4', 'B5'], 'C': ['C3', 'C4', 'C5']})
df1 = pd.DataFrame({
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    }, index=[0, 1, 2, 3])

df2 = pd.DataFrame({
        "A": ["A4", "A5", "A6", "A7"],
        "B": ["B4", "B5", "B6", "B7"],
        "C": ["C4", "C5", "C6", "C7"],
        "D": ["D4", "D5", "D6", "D7"],
    }, index=[4, 5, 6, 7])

df3 = pd.DataFrame({
        "A": ["A8", "A9", "A10", "A11"],
        "B": ["B8", "B9", "B10", "B11"],
        "C": ["C8", "C9", "C10", "C11"],
        "D": ["D8", "D9", "D10", "D11"],
    }, index=[8, 9, 10, 11])

df4 = pd.DataFrame({
        "B": ["B2", "B3", "B6", "B7"],
        "D": ["D2", "D3", "D6", "D7"],
        "F": ["F2", "F3", "F6", "F7"],
    }, index=[2, 3, 6, 7])

# pandas.concat([df1, df2], axis=0)
# pandas.concat([df1, df2], axis=1, keys=["x", "y"], ignore_index=True, join='inner')
pandas.concat([df1, df4], axis=1, join='inner')
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %% [markdown]
# merge()

# %%
left = pd.DataFrame(
    {
        "key1": ["K0", "K0", "K1", "K2"],
        "key2": ["K0", "K1", "K0", "K1"],
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
    }
)

right = pd.DataFrame(
    {
        "key1": ["K0", "K1", "K1", "K2"],
        "key2": ["K0", "K0", "K0", "K0"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    }
)

print(pandas.DataFrame(left))
print()
print(pandas.DataFrame(right))
pandas.merge(left, right)
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3
#
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
ev_dataset = pandas.read_csv('./data/Electric_Vehicle_Population_Data.csv')
ev_dataset.rename(columns={ 'County' : 'Country'}, inplace=True)
# ev_dataset[ev_dataset['Electric Range'].apply(lambda x: x != 0)]
ev_dataset['Electric Range'].sort_values(ascending=True)
# Out:
# 159466      0
# 62565       0
# 123635      0
# 62563       0
# 123638      0
# 123639      0
# 62559       0
# 62558       0
# 62557       0
# 123640      0
# 123641      0
# 123643      0
# 123644      0
# 123645      0
# 62550       0
# 62549       0
# 123646      0
# 62546       0
# 62566       0
# 62545       0
# 62569       0
# 123632      0
# 62597       0
# 62596       0
# 62595       0
# 123615      0
# 62592       0
# 62589       0
# 123618      0
# 62585       0
#          ...
# 118628    337
# 123556    337
# 159335    337
# 44897     337
# 4285      337
# 127999    337
# 120226    337
# 5393      337
# 102260    337
# 89925     337
# 159395    337
# 43729     337
# 72246     337
# 49562     337
# 116087    337
# 108202    337
# 90868     337
# 154256    337
# 99906     337
# 69146     337
# 116028    337
# 117883    337
# 33525     337
# 43118     337
# 11849     337
# 144557    337
# 108846    337
# 95203     337
# 158226    337
# 36171     337
# ...

# %%
titanic = pandas.read_csv('./data/kapal_titanic.csv')
titanic["deck"].isna().sum() # 688
titanic["deck"].notnull().sum() # 203
titanic["deck"].shape # 891
titanic["deck"].dropna()
# Out:
# 1      C
# 3      C
# 6      E
# 10     G
# 11     C
# 21     D
# 23     A
# 27     C
# 31     B
# 52     D
# 54     B
# 55     C
# 61     B
# 62     C
# 66     F
# 75     F
# 88     C
# 92     E
# 96     A
# 97     D
# 102    D
# 110    C
# 118    B
# 123    E
# 124    D
# 128    F
# 136    D
# 137    C
# 139    B
# 148    F
#       ..
# 751    E
# 759    B
# 763    B
# 765    D
# 772    E
# 776    F
# 779    B
# 781    B
# 782    D
# 789    B
# 796    D
# 802    B
# 806    A
# 809    E
# 815    B
# 820    B
# 823    E
# 829    B
# 835    E
# 839    C
# 849    C
# 853    D
# 857    E
# 862    D
# 867    A
# 871    D
# 872    B
# 879    C
# 887    B
# 889    C
# Name: deck, Length: 203, dtype: object
